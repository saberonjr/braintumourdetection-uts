# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()

# %%
# !yolo checks

# %%
#!yolo task=detect mode=train model = yolov8n.pt data = {dataset.location}/data.yaml epoch =20 imgsz = 120

# %%
#!yolo detect train model=yolov8n.pt data={dataset.location}/data.yaml epochs=20 imgsz=120

# %%
# !yolo detect train model=yolov8n.pt data=/content/drive/MyDrive/Test_Data/data.yaml epochs=10 imgsz=244

# %%
Image(filename=f'/content/runs/detect/train/confusion_matrix.png', width=600)

# %%
Image(f'/content/runs/detect/train/results.png', width=1000)

# %%
# !yolo detect train mode=val model = /content/runs/detect/train/weights/best.pt data=/content/drive/MyDrive/Test_Data/data.yaml
# Out:
# Ultralytics YOLOv8.1.31 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/Test_Data/valid/labels.cache... 80 images, 1 backgrounds, 0 corrupt: 100% 80/80 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 5/5 [00:06<00:00,  1.26s/it]
#                    all         80        162      0.752      0.168      0.317      0.159
#                 label0         80         41          1     0.0384      0.305      0.139
#                 label1         80         79      0.504      0.443       0.37      0.186
#                 label2         80         42      0.751     0.0238      0.275      0.152
# Speed: 1.7ms preprocess, 58.2ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo detect predict model=/content/runs/detect/train/weights/best.pt conf = 0.8 source=/content/drive/MyDrive/Brain Tumor Project/input

# %%
import glob
from IPython.display import Image, display

# Get the paths of all images in the directory
image_paths = glob.glob('/content/runs/detect/predict/*.jpg')

# Display each image
for image_path in image_paths:
    display(Image(filename=image_path, width= 200))
    print('\n')
    print('\n')
    print('\n')
